# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Dataset .csv')
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df['Cuisines'].fillna('unknown', inplace=True)
# Out:
# C:\Users\Saran\AppData\Local\Temp\ipykernel_6176\929747886.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cuisines'].fillna('unknown', inplace=True)

# %%
print(df.isnull().values.any())
# Out:
# False

# %%
df['Cuisines'].value_counts()
# Out:
# Cuisines
# North Indian                                             936
# North Indian, Chinese                                    511
# Chinese                                                  354
# Fast Food                                                354
# North Indian, Mughlai                                    334
#                                                         ...
# Bengali, Fast Food                                         1
# North Indian, Rajasthani, Asian                            1
# Chinese, Thai, Malaysian, Indonesian                       1
# Bakery, Desserts, North Indian, Bengali, South Indian      1
# Italian, World Cuisine                                     1
# Name: count, Length: 1826, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

categorical_columns = ['City', 'Cuisines', 'Currency', 'Has Table booking', 
                       'Has Online delivery', 'Is delivering now', 'Rating text']

label_encoders = {}
for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le  # Store label encoders for later use

# Verify that all missing values are handled
df.isnull().sum().sum()
# Out:
# 0

# %%
def recommend_restaurants(user_city, user_cuisine, user_price_range, top_n=5):
    # Convert user city and cuisine to encoded values
    if user_city not in label_encoders['City'].classes_ or user_cuisine not in label_encoders['Cuisines'].classes_:
        return "City or Cuisine not found in the dataset."
    
    city_encoded = label_encoders['City'].transform([user_city])[0]
    cuisine_encoded = label_encoders['Cuisines'].transform([user_cuisine])[0]

    # Filter restaurants based on user's preferred city and price range
    filtered_df = df[(df['City'] == city_encoded) & (df['Price range'] == user_price_range)].copy()

    if filtered_df.empty:
        return "No restaurants match your criteria."

    # Create a feature vector combining cuisine, price range, rating, and votes
    filtered_df['Feature_Vector'] = filtered_df.apply(lambda x: f"{x['Cuisines']} {x['Price range']} {x['Aggregate rating']} {x['Votes']}", axis=1)

    # Convert text features into numerical vectors using TF-IDF
    vectorizer = TfidfVectorizer()
    feature_matrix = vectorizer.fit_transform(filtered_df['Feature_Vector'])

    # Compute similarity between all restaurants
    similarity_matrix = cosine_similarity(feature_matrix)

    # Find the index of the restaurant matching the user's preferred cuisine
    target_index = filtered_df[filtered_df['Cuisines'] == cuisine_encoded].index

    if target_index.empty:
        return "No similar restaurants found."

    # Get similarity scores and sort them
    target_index = target_index[0]  # Take the first matching index
    similarity_scores = list(enumerate(similarity_matrix[target_index]))
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)

    # Get the top N similar restaurants (excluding the first one, as it's the input itself)
    recommended_indices = [i[0] for i in similarity_scores[1:top_n+1]]
    recommendations = filtered_df.iloc[recommended_indices][['Restaurant Name', 'Cuisines', 'Aggregate rating', 'Votes']]

    # Decode cuisine names from numeric values
    recommendations['Cuisines'] = recommendations['Cuisines'].apply(lambda x: label_encoders['Cuisines'].inverse_transform([x])[0])

    return recommendations

# %%
# Function to take user input
def get_user_input():
    user_city = input("Enter your city: ")
    user_cuisine = input("Enter your preferred cuisine: ")
    user_price_range = int(input("Enter your price range (1-4): "))
    return user_city, user_cuisine, user_price_range

# Get user input
user_city, user_cuisine, user_price_range = get_user_input()

# Run the recommendation system
recommendations = recommend_restaurants(user_city, user_cuisine, user_price_range)
print(recommendations)
# Out:
# Enter your city:  Makati City
# Enter your preferred cuisine:  Japanese
# Enter your price range (1-4):  3
#     Restaurant Name                    Cuisines  Aggregate rating  Votes
# 0  Le Petit Souffle  French, Japanese, Desserts               4.8    314
